# %% [markdown]
# #### Pandas is a powerful and open-source Python library. The Pandas library is used for data manipulation and analysis. Pandas consist of data structures and functions to perform efficient operations on data.
# #### pandas supports all format such as csv, json, sql, xlsx and etc.

# %%
import pandas as pd

# %% [markdown]
# #### In pandas we have two important data type :
# 1. Series: This count as 1-dimensional dataset
# 2. Dataframe: This one count as multi-dimensional dataset

# %%
from IPython.display import Image
Image(filename='pandas_image.png')

# %% [markdown]
# ### Series

# %%
dict_1 = {'armin': 24, 'arta': 18, 'soorena': 19, 'alhan': 19, 'parsa': 16}

# %%
print(pd.Series(dict_1))
# Out:
# armin      24
# arta       18
# soorena    19
# alhan      19
# parsa      16
# dtype: int64

# %%
lst = [24, 18, 19, 19, 16]

# %%
print(pd.Series(lst))
# Out:
# 0    24
# 1    18
# 2    19
# 3    19
# 4    16
# dtype: int64

# %%
print(pd.Series(lst, index = ['armin', 'arta', 'soorena', 'alhan', 'parsa']))
# Out:
# armin      24
# arta       18
# soorena    19
# alhan      19
# parsa      16
# dtype: int64

# %%
series_1 = pd.Series(lst, index = ['armin', 'arta', 'soorena', 'alhan', 'parsa'])

# %%
dict_1 = {'armin': 24, 'arta': 18, 'soorena': 19, 'alhan': 19, 'parsa': 16}

# %%
print(dict_1.keys())
print(dict_1.values())
# Out:
# dict_keys(['armin', 'arta', 'soorena', 'alhan', 'parsa'])
# dict_values([24, 18, 19, 19, 16])

# %%
print(series_1.index)
print(series_1.values)
# Out:
# Index(['armin', 'arta', 'soorena', 'alhan', 'parsa'], dtype='object')
# [24 18 19 19 16]

# %%
# Dictionary
dict_1['armin']
# Out:
# 24

# %%
# Series
print(series_1['armin'])
print(series_1.armin)
print(series_1[0])
# Out:
# 24
# 24
# 24

# %%
print(dict_1['armin', 'soorena'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(dict_1['armin', 'soorena'])
#
# KeyError: ('armin', 'soorena')

# %%
print(series_1[['armin', 'soorena']])
# Out:
# armin      24
# soorena    19
# dtype: int64

# %%
print(series_1[[0, 2]])
# Out:
# armin      24
# soorena    19
# dtype: int64

# %%
print(series_1[0:3])
# Out:
# armin      24
# arta       18
# soorena    19
# dtype: int64

# %%
print(series_1['armin': 'soorena'])
# Out:
# armin      24
# arta       18
# soorena    19
# dtype: int64

# %%
print(series_1[[True, True, False, False, True]])
# Out:
# armin    24
# arta     18
# parsa    16
# dtype: int64

# %% [markdown]
# #### Series Oprations

# %%
print(series_1.mean())
# Out:
# 19.2

# %%
print(series_1 > series_1.mean())
# Out:
# armin       True
# arta       False
# soorena    False
# alhan      False
# parsa      False
# dtype: bool

# %%
print(series_1[series_1 > series_1.mean()])
# Out:
# armin    24
# dtype: int64

# %% [markdown]
# #### This is the capability of Series.

# %% [markdown]
# #### Now let's work with DataFrame

# %%
scores = {'Math':[12, 14, 16, 18, 20], 'Programming':[1, 2, 3, 4, 5], 'Physics':[13.5, 15.5, 17.5, 20, 10]}

# %%
df = pd.DataFrame(scores)
print(df)
# Out:
#    Math  Programming  Physics
# 0    12            1     13.5
# 1    14            2     15.5
# 2    16            3     17.5
# 3    18            4     20.0
# 4    20            5     10.0

# %%
df.shape
# Out:
# (5, 3)

# %%
# finding rows & cols 
print(df.columns)
# Out:
# Index(['Math', 'Programming', 'Physics'], dtype='object')

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(df.values)
# Out:
# [[12.   1.  13.5]
#  [14.   2.  15.5]
#  [16.   3.  17.5]
#  [18.   4.  20. ]
#  [20.   5.  10. ]]

# %%
import numpy as np
dataset = np.array(df.values)
print(dataset)
# Out:
# [[12.   1.  13.5]
#  [14.   2.  15.5]
#  [16.   3.  17.5]
#  [18.   4.  20. ]
#  [20.   5.  10. ]]

# %%
dataset = dataset.reshape(3, -1)
print(dataset)
# Out:
# [[12.   1.  13.5 14.   2. ]
#  [15.5 16.   3.  17.5 18. ]
#  [ 4.  20.  20.   5.  10. ]]

# %% [markdown]
# #### Some methods for describing DataFrames

# %%
print(df)
# Out:
#    Math  Programming  Physics
# 0    12            1     13.5
# 1    14            2     15.5
# 2    16            3     17.5
# 3    18            4     20.0
# 4    20            5     10.0

# %%
df.head(2)
# Out:
#    Math  Programming  Physics
# 0    12            1     13.5
# 1    14            2     15.5

# %%
df.tail(2)
# Out:
#    Math  Programming  Physics
# 3    18            4     20.0
# 4    20            5     10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Math         5 non-null      int64
#  1   Programming  5 non-null      int64
#  2   Physics      5 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 248.0 bytes

# %%
df.describe()
# Out:
#             Math  Programming    Physics
# count   5.000000     5.000000   5.000000
# mean   16.000000     3.000000  15.300000
# std     3.162278     1.581139   3.817722
# min    12.000000     1.000000  10.000000
# 25%    14.000000     2.000000  13.500000
# 50%    16.000000     3.000000  15.500000
# 75%    18.000000     4.000000  17.500000
# max    20.000000     5.000000  20.000000

# %% [markdown]
# #### Working with element of dataframe

# %%
# This is a series
df['Math']
# Out:
# 0    12
# 1    14
# 2    16
# 3    18
# 4    20
# Name: Math, dtype: int64

# %%
df.Math
# Out:
# 0    12
# 1    14
# 2    16
# 3    18
# 4    20
# Name: Math, dtype: int64

# %%
df["Math"] > 14
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Math, dtype: bool

# %% [markdown]
# #### Let's get familiar with loc & iloc

# %%
# iloc method
print(df)
# Out:
#    Math  Programming  Physics
# 0    12            1     13.5
# 1    14            2     15.5
# 2    16            3     17.5
# 3    18            4     20.0
# 4    20            5     10.0

# %%
print(df.iloc[2, 2])
# Out:
# 17.5

# %%
print(df.iloc[1:4, 0:3])
# Out:
#    Math  Programming  Physics
# 1    14            2     15.5
# 2    16            3     17.5
# 3    18            4     20.0

# %%
print(df.iloc[[1, 4], 1:])
# Out:
#    Programming  Physics
# 1            2     15.5
# 4            5     10.0

# %%
print(df.iloc[[True, False, True, False, True], [0, 2]])
# Out:
#    Math  Physics
# 0    12     13.5
# 2    16     17.5
# 4    20     10.0

# %%
# loc method
print(df)
# Out:
#    Math  Programming  Physics
# 0    12            1     13.5
# 1    14            2     15.5
# 2    16            3     17.5
# 3    18            4     20.0
# 4    20            5     10.0

# %%
print(df.loc[3, 'Programming'])
# Out:
# 4

# %%
print(df.loc[1:4, "Math":"Physics"])
# Out:
#    Math  Programming  Physics
# 1    14            2     15.5
# 2    16            3     17.5
# 3    18            4     20.0
# 4    20            5     10.0

# %% [markdown]
# #### Attention: loc is a label based mathod so, its gramer is : [start, end]

# %%
print(df.loc[[1, 3, 4], ['Math', 'Physics']])
# Out:
#    Math  Physics
# 1    14     15.5
# 3    18     20.0
# 4    20     10.0

# %%
print(df.loc[[True, True, False, False, False], ["Programming", "Physics"]])
# Out:
#    Programming  Physics
# 0            1     13.5
# 1            2     15.5

# %% [markdown]
# #### Working with data using pandas

# %%
import pandas as pd

# %%
iris_data = pd.read_csv('iris_1.csv')

# %%
print(iris_data)
# Out:
#      5.1  3.5  1.4   .2     Setosa
# 0    4.9  3.0  1.4  0.2     Setosa
# 1    4.7  3.2  1.3  0.2     Setosa
# 2    4.6  3.1  1.5  0.2     Setosa
# 3    5.0  3.6  1.4  0.2     Setosa
# 4    5.4  3.9  1.7  0.4     Setosa
# ..   ...  ...  ...  ...        ...
# 144  6.7  3.0  5.2  2.3  Virginica
# 145  6.3  2.5  5.0  1.9  Virginica
# 146  6.5  3.0  5.2  2.0  Virginica
# 147  6.2  3.4  5.4  2.3  Virginica
# 148  5.9  3.0  5.1  1.8  Virginica
#
# [149 rows x 5 columns]

# %%
iris_data = pd.read_csv('iris_1.csv', sep = '\t')

# %%
print(iris_data)
# Out:
#          5.1,3.5,1.4,.2,"Setosa"
# 0          4.9,3,1.4,.2,"Setosa"
# 1        4.7,3.2,1.3,.2,"Setosa"
# 2        4.6,3.1,1.5,.2,"Setosa"
# 3          5,3.6,1.4,.2,"Setosa"
# 4        5.4,3.9,1.7,.4,"Setosa"
# ..                           ...
# 144    6.7,3,5.2,2.3,"Virginica"
# 145    6.3,2.5,5,1.9,"Virginica"
# 146      6.5,3,5.2,2,"Virginica"
# 147  6.2,3.4,5.4,2.3,"Virginica"
# 148    5.9,3,5.1,1.8,"Virginica"
#
# [149 rows x 1 columns]

# %%
iris_data = pd.read_csv('iris_1.csv', header = None, 
                        names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label'])

# %%
print(iris_data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   label
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      label
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   label         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_features = iris_data.iloc[: , :-1]

# %%
print(iris_features)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
iris_labels = iris_data.iloc[: , -1:]

# %%
print(iris_labels)
# Out:
#          label
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %%
data_iris = pd.read_csv('iris_2.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 data_iris = pd.read_csv('iris_2.csv')
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/anaconda3/envs/arminkernel/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 3, saw 5

# %%
data_iris = pd.read_csv('iris_2.csv', header = None, 
                        names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label'],
                       skiprows = 2)

# %%
data_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      label
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data_iris_2 = pd.read_csv('iris_3.csv', header = None, 
                        names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label'],
                       skiprows = 2)

# %%
print(data_iris_2)
# Out:
#          sepal_length  sepal_width  petal_length  petal_width      label
# 0                 5.1          3.5           1.4          0.2     Setosa
# 1    # testing values          NaN           NaN          NaN        NaN
# 2                 4.9          3.0           1.4          0.2     Setosa
# 3                 4.7          3.2           1.3          0.2     Setosa
# 4                 4.6          3.1           1.5          0.2     Setosa
# ..                ...          ...           ...          ...        ...
# 148               6.7          3.0           5.2          2.3  Virginica
# 149               6.3          2.5           5.0          1.9  Virginica
# 150               6.5          3.0           5.2          2.0  Virginica
# 151               6.2          3.4           5.4          2.3  Virginica
# 152               5.9          3.0           5.1          1.8  Virginica
#
# [153 rows x 5 columns]

# %%
data_iris_2 = pd.read_csv('iris_3.csv', header = None, 
                        names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label'],
                       skiprows = 2,
                         comment = '#')

# %%
print(data_iris_2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      label
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data_iris_3 = pd.read_csv('iris_3.csv', header = None, 
                        names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label'],
                       skiprows = 2,
                         comment = '#', 
                         usecols = ['sepal_length', 'petal_length'])

# %%
print(data_iris_3)
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# ..            ...           ...
# 145           6.7           5.2
# 146           6.3           5.0
# 147           6.5           5.2
# 148           6.2           5.4
# 149           5.9           5.1
#
# [150 rows x 2 columns]
